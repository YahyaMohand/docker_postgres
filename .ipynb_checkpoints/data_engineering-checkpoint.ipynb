# %%
import pandas as pd
from sqlalchemy import create_engine
pd.set_option('display.max_columns', None)

# %%
engine = create_engine('postgresql://root:root@localhost:5433/taxi')

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM public.green_taxi_data;"""
data = pd.read_sql(query, con=engine)

# %%
data.dtypes
# Out:
# index                      int64
# VendorID                   int64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID                 int64
# PULocationID               int64
# DOLocationID               int64
# passenger_count            int64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                 object
# improvement_surcharge    float64
# total_amount             float64
# payment_type               int64
# trip_type                  int64
# congestion_surcharge     float64
# dtype: object

# %%
data.lpep_pickup_datetime = pd.to_datetime(data.lpep_pickup_datetime)
data.lpep_dropoff_datetime = pd.to_datetime(data.lpep_dropoff_datetime)

# %%
data.dtypes
# Out:
# index                             int64
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                   int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                      int64
# trip_type                         int64
# congestion_surcharge            float64
# dtype: object

# %%
taxi_trips_jan = data[data['lpep_pickup_datetime'].dt.date.astype(str) == '2019-01-15']

# %%
len(taxi_trips_jan)
# Out:
# 20689

# %%
largest_trip_distance = data.loc[data['trip_distance'] == data.trip_distance.max(),
                            ['lpep_pickup_datetime', 'trip_distance']]
largest_trip_distance
# Out:
#        lpep_pickup_datetime  trip_distance
# 297377  2019-01-15 19:27:58         117.99

# %%
trips_had_passengers_3 = data.loc[(data['lpep_pickup_datetime'].dt.date.astype(str) == '2019-01-01') & 
                          (data['passenger_count'] == 3) ,
                          ['lpep_pickup_datetime','passenger_count']]
trips_had_passengers_3
# Out:
#       lpep_pickup_datetime  passenger_count
# 31     2019-01-01 00:08:07                3
# 40     2019-01-01 00:31:28                3
# 67     2019-01-01 00:39:51                3
# 149    2019-01-01 00:35:40                3
# 185    2019-01-01 00:09:09                3
# ...                    ...              ...
# 14666  2019-01-01 22:15:36                3
# 14753  2019-01-01 23:46:40                3
# 14830  2019-01-01 23:20:47                3
# 14959  2019-01-01 23:16:50                3
# 14970  2019-01-01 23:34:57                3
#
# [254 rows x 2 columns]

# %%
trips_had_passengers_2 = data.loc[(data['lpep_pickup_datetime'].dt.date.astype(str) == '2019-01-01') & 
                          (data['passenger_count'] == 2) ,
                          ['lpep_pickup_datetime','passenger_count']]
trips_had_passengers_2
# Out:
#       lpep_pickup_datetime  passenger_count
# 1      2019-01-01 00:10:16                2
# 2      2019-01-01 00:27:11                2
# 3      2019-01-01 00:46:20                2
# 11     2019-01-01 00:13:48                2
# 32     2019-01-01 00:40:23                2
# ...                    ...              ...
# 14971  2019-01-01 23:33:40                2
# 14996  2019-01-01 23:10:16                2
# 14997  2019-01-01 23:34:15                2
# 15029  2019-01-01 23:08:14                2
# 15032  2019-01-01 23:42:48                2
#
# [1282 rows x 2 columns]

# %%
len(data['PULocationID'].unique())
# Out:
# 256

# %%
largest_tip = data.loc[data.groupby('PULocationID')['tip_amount'].agg(pd.Series.idxmax)]
largest_tip
# Out:
#          index  VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 336353  336353         2  2019-01-17 16:23:58   2019-01-17 16:24:01
# 152452  152452         1  2019-01-08 22:02:09   2019-01-08 22:12:14
# 524679  524679         2  2019-01-26 20:38:54   2019-01-26 21:02:12
# 370205  370205         2  2019-01-19 03:20:18   2019-01-19 03:34:38
# 102537  102537         2  2019-01-06 12:33:30   2019-01-06 13:00:36
# ...        ...       ...                  ...                   ...
# 306327  306327         2  2019-01-16 10:03:45   2019-01-16 10:38:13
# 518023  518023         2  2019-01-26 15:32:48   2019-01-26 15:42:24
# 83869    83869         2  2019-01-05 13:31:22   2019-01-05 14:05:41
# 181606  181606         1  2019-01-10 11:25:31   2019-01-10 12:22:40
# 72525    72525         2  2019-01-04 20:12:08   2019-01-04 20:12:23
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 336353                  N           5             1             1
# 152452                  N           1             3            32
# 524679                  N           1             4            90
# 370205                  N           1             5           204
# 102537                  N           1             6           125
# ...                   ...         ...           ...           ...
# 306327                  N           1           261           163
# 518023                  N           5           262            74
# 83869                   N           1           263           132
# 181606                  N           1           264           236
# 72525                   N           1           265           265
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 336353                1           0.00        86.00    0.0      0.0
# 152452                2           2.30         9.50    0.5      0.5
# 524679                1           2.37        15.00    0.5      0.5
# 370205                1           3.80        13.50    0.5      0.5
# 102537                3          12.13        35.00    0.0      0.5
# ...                 ...            ...          ...    ...      ...
# 306327                5           7.85        28.50    0.0      0.5
# 518023                1           1.54         0.35    0.0      0.0
# 83869                 1          18.53        49.50    0.0      0.5
# 181606                1          24.40        72.50    0.5      0.5
# 72525                 1           0.00         2.50    0.5      0.5
#
#         tip_amount  tolls_amount ehail_fee  improvement_surcharge  \
# 336353       17.20          0.00      None                    0.0
# 152452        3.24          0.00      None                    0.3
# 524679        2.00          0.00      None                    0.3
# 370205        4.44          0.00      None                    0.3
# 102537        0.00         17.28      None                    0.3
# ...            ...           ...       ...                    ...
# 306327        7.32          0.00      None                    0.3
# 518023       35.00          0.00      None                    0.0
# 83869        14.02          5.76      None                    0.3
# 181606       18.40          0.00      None                    0.3
# 72525        50.00          0.00      None                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 336353        103.20             1          2                   NaN
# 152452         14.04             1          1                   NaN
# 524679         18.30             1          1                   NaN
# 370205         19.24             1          1                   NaN
# 102537         53.08             1          1                   NaN
# ...              ...           ...        ...                   ...
# 306327         36.62             1          1                   NaN
# 518023         35.35             1          2                   NaN
# 83869          70.08             1          1                   NaN
# 181606         92.20             1          1                   NaN
# 72525          53.80             1          1                   NaN
#
# [256 rows x 21 columns]

# %% [markdown]
# NOTE: The PULocationID = 7 its mean the astoria city,
#         and DOLocationID = 146 its mean the Long Island City/Queens Plaza

# %%
largest_tip.loc[largest_tip['PULocationID'] == 7 ,
           ['PULocationID', 'DOLocationID', 'tip_amount']]
# Out:
#         PULocationID  DOLocationID  tip_amount
# 506162             7           146        88.0
